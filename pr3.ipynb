# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('nba.csv')
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.shape
# Out:
# (458, 9)

# %%
data.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
null_col=[]

for col in data.columns:
    if data[col].isnull().any()==True:
        print(f"{col}")
        null_col.append(col)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary

# %%
for col in null_col:
    if data[col].isnull().sum()==1:
        data=data.dropna(subset=[col])
    elif data[col].dtype=='float' or data[col].dtype=='int':
        data=data.fillna(data[col].mean())
    else:
        data=data.fillna(data[col].mode()[0])

# %%
data.shape
# Out:
# (457, 9)

# %%
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
data['Salary'] = pd.to_numeric(data['Salary'], errors='coerce')

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {data[col].mean()}")
# Out:
# Number : 17.678336980306344
# Age : 26.938730853391686
# Weight : 221.52297592997812
# Salary : 4842684.105381166

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {np.mean(data[col])}")
# Out:
# Number : 17.678336980306344
# Age : 26.938730853391686
# Weight : 221.52297592997812
# Salary : 4842684.105381166

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {data[col].median()}")
# Out:
# Number : 13.0
# Age : 26.0
# Weight : 220.0
# Salary : 2839073.0

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {np.median(data[col])}")
# Out:
# Number : 13.0
# Age : 26.0
# Weight : 220.0
# Salary : nan

# %%
for col in data.columns:
    print(f"{col}:{data[col].mode()[0]}")
# Out:
# Name:Aaron Brooks
# Team:New Orleans Pelicans
# Number:5.0
# Position:SG
# Age:24.0
# Height:6-9
# Weight:220.0
# College:New Orleans Pelicans
# Salary:947276.0

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {data[col].min()}")

for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {np.min(data[col])}")
# Out:
# Number : 0.0
# Age : 19.0
# Weight : 161.0
# Salary : 30888.0
# Number : 0.0
# Age : 19.0
# Weight : 161.0
# Salary : 30888.0

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {data[col].max()}")

for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {np.max(data[col])}")
# Out:
# Number : 99.0
# Age : 40.0
# Weight : 307.0
# Salary : 25000000.0
# Number : 99.0
# Age : 40.0
# Weight : 307.0
# Salary : 25000000.0

# %%
for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {data[col].std()}")

for col in data.columns:
    if data[col].dtype =='float' or data[col].dtype =='int':
        print(f"{col} : {np.std(data[col])}")
# Out:
# Number : 15.966090405679644
# Age : 4.404016424405833
# Weight : 26.36834262669547
# Salary : 5229237.598910348
# Number : 15.948612468962038
# Age : 4.399195386918678
# Weight : 26.339477437280433
# Salary : 5223371.935147341

# %%
grouped_data=data.groupby('Age')['Salary'].describe()
grouped_data
# Out:
#       count          mean           std        min         25%        50%  \
# Age
# 19.0    2.0  1.930440e+06  2.791658e+05  1733040.0  1831740.00  1930440.0
# 20.0   19.0  2.725791e+06  1.510913e+06   525093.0  1636920.00  2481720.0
# 21.0   19.0  2.067380e+06  1.412350e+06   525093.0  1235480.00  1584480.0
# 22.0   26.0  2.357963e+06  1.517378e+06   525093.0  1169190.00  1793880.0
# 23.0   39.0  2.034746e+06  2.728292e+06    30888.0   637546.50  1175880.0
# 24.0   45.0  3.785300e+06  4.803384e+06   525093.0   900000.00  1509360.0
# 25.0   44.0  3.930867e+06  4.558463e+06    55722.0   947276.00  1305660.0
# 26.0   36.0  6.866566e+06  6.100471e+06   134215.0  1336790.50  3325000.0
# 27.0   40.0  6.676741e+06  6.831984e+06    55722.0  1030105.25  3425510.0
# 28.0   30.0  5.110189e+06  4.316627e+06   206192.0  1740131.50  4194803.5
# 29.0   27.0  6.224177e+06  4.870706e+06   111444.0  1910000.00  5543725.0
# 30.0   30.0  7.061859e+06  5.408670e+06   947276.0  2977205.00  5867803.0
# ...

# %%
grouped_data=data.groupby('Age')['Salary'].agg(
     Mean='mean',
    Median='median',
    Minimum='min',
    Maximum='max',
    Std_Dev='std')
grouped_data
# Out:
#               Mean     Median    Minimum     Maximum       Std_Dev
# Age
# 19.0  1.930440e+06  1930440.0  1733040.0   2127840.0  2.791658e+05
# 20.0  2.725791e+06  2481720.0   525093.0   5703600.0  1.510913e+06
# 21.0  2.067380e+06  1584480.0   525093.0   5758680.0  1.412350e+06
# 22.0  2.357963e+06  1793880.0   525093.0   6331404.0  1.517378e+06
# 23.0  2.034746e+06  1175880.0    30888.0  16000000.0  2.728292e+06
# 24.0  3.785300e+06  1509360.0   525093.0  16407501.0  4.803384e+06
# 25.0  3.930867e+06  1305660.0    55722.0  15851950.0  4.558463e+06
# 26.0  6.866566e+06  3325000.0   134215.0  17120106.0  6.100471e+06
# 27.0  6.676741e+06  3425510.0    55722.0  20158622.0  6.831984e+06
# 28.0  5.110189e+06  4194803.5   206192.0  19689000.0  4.316627e+06
# 29.0  6.224177e+06  5543725.0   111444.0  16407500.0  4.870706e+06
# 30.0  7.061859e+06  5867803.0   947276.0  22359364.0  5.408670e+06
# 31.0  8.511397e+06  5439487.0   947276.0  22970500.0  7.170163e+06
# ...

# %%
# right=False means if 19-23 the take 19 dont take 23
data['AgeGroup'] = pd.cut(data['Age'], bins=[19, 23, 27, 31, 35,39,43], labels=['19-22', '23-26', '27-30', '31-34','35-38','39-42'],right=False)
grouped_data=data.groupby('AgeGroup')['Salary'].describe()
grouped_data
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19432\1838859670.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data=data.groupby('AgeGroup')['Salary'].describe()
#           count          mean           std       min        25%        50%  \
# AgeGroup
# 19-22      66.0  2.367245e+06  1.463244e+06  525093.0  1252560.0  1881120.0
# 23-26     164.0  4.084440e+06  4.917529e+06   30888.0   947276.0  1641039.5
# 27-30     127.0  6.301448e+06  5.557506e+06   55722.0  1410000.0  4950000.0
# 31-34      59.0  7.095963e+06  6.528382e+06  200600.0  2175000.0  5016000.0
# 35-38      25.0  3.830744e+06  4.914137e+06  222888.0   947276.0  2854940.0
# 39-42       5.0  3.807299e+06  3.354394e+06  250750.0   947726.0  4088019.0
#
#                   75%         max
# AgeGroup
# ...

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
grouped_data=df.groupby('Species').describe()
grouped_data.T
# Out:
# Species              Iris-setosa  Iris-versicolor  Iris-virginica
# Id            count    50.000000        50.000000       50.000000
#               mean     25.500000        75.500000      125.500000
#               std      14.577380        14.577380       14.577380
#               min       1.000000        51.000000      101.000000
#               25%      13.250000        63.250000      113.250000
#               50%      25.500000        75.500000      125.500000
#               75%      37.750000        87.750000      137.750000
#               max      50.000000       100.000000      150.000000
# SepalLengthCm count    50.000000        50.000000       50.000000
#               mean      5.006000         5.936000        6.588000
#               std       0.352490         0.516171        0.635880
#               min       4.300000         4.900000        4.900000
#               25%       4.800000         5.600000        6.225000
# ...

# %%
#describe each class of Species
def basic_statistics(df):
    print("\nIris-setosa")
    print(df[df.Species=='Iris-setosa'].describe().transpose())
    print("\nIris-versicolor")
    print(df[df.Species=='Iris-versicolor'].describe().transpose())
    print("\nIris-virginica")
    print(df[df.Species=='Iris-virginica'].describe().transpose())
basic_statistics(df)
# Out:
# Iris-setosa
#                count    mean        std  min     25%   50%     75%   max
# Id              50.0  25.500  14.577380  1.0  13.250  25.5  37.750  50.0
# SepalLengthCm   50.0   5.006   0.352490  4.3   4.800   5.0   5.200   5.8
# SepalWidthCm    50.0   3.418   0.381024  2.3   3.125   3.4   3.675   4.4
# PetalLengthCm   50.0   1.464   0.173511  1.0   1.400   1.5   1.575   1.9
# PetalWidthCm    50.0   0.244   0.107210  0.1   0.200   0.2   0.300   0.6
#
# Iris-versicolor
#                count    mean        std   min     25%    50%    75%    max
# Id              50.0  75.500  14.577380  51.0  63.250  75.50  87.75  100.0
# SepalLengthCm   50.0   5.936   0.516171   4.9   5.600   5.90   6.30    7.0
# SepalWidthCm    50.0   2.770   0.313798   2.0   2.525   2.80   3.00    3.4
# PetalLengthCm   50.0   4.260   0.469911   3.0   4.000   4.35   4.60    5.1
# PetalWidthCm    50.0   1.326   0.197753   1.0   1.200   1.30   1.50    1.8
#
# Iris-virginica
# ...
